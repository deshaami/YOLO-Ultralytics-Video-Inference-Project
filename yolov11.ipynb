# %%
! git clone https://github.com/ultralytics/ultralytics.git
! cd ultralytics

! conda create -n yolo11 python=3.11
! conda activate yolo11
! pip install ultralytics

! yolo detect predict model=yolo11x.pt source='/content/MTB Motivation - 1 Minute Edits.mp4' save=True


#Display output

from IPython.display import HTML
from base64 import b64encode
import os

# Path to your video file
video_path = '/content/runs/detect/predict/MTB Motivation - 1 Minute Edits.avi'

# Convert .avi to .mp4 using ffmpeg (show only progress bar, no verbose output)
output_path = "Object detectipon.mp4"
# !apt-get install ffmpeg -y
# Use f-strings for variable substitution and ensure the output file extension is .mp4
# !ffmpeg -i "{video_path}" -vcodec libx264 -loglevel quiet -stats "{output_path}"

# Function to display video in Colab
def display_video(video_file):
    video_type = video_file.split('.')[-1]  # Get video file extension
    video = open(video_file, "rb").read()
    data_url = "data:video/{};base64,".format(video_type) + b64encode(video).decode()
    return HTML('<video width="600" controls><source src="{}" type="video/{}"></video>'.format(data_url, video_type))

# Display the converted .mp4 video
display_video(output_path)

! yolo segment predict model=yolo11x.pt source='/content/background video _ people _ walking _.mp4' save=True

#Display output

from IPython.display import HTML
from base64 import b64encode
import os

# Path to your video file
video_path = '/content/runs/detect/predict4/background video _ people _ walking _.avi'

# Convert .avi to .mp4 using ffmpeg (show only progress bar, no verbose output)
output_path = "Instance segmentation.mp4"
# !apt-get install ffmpeg -y
# Use f-strings for variable substitution and ensure the output file extension is .mp4
# !ffmpeg -i "{video_path}" -vcodec libx264 -loglevel quiet -stats "{output_path}"

# Function to display video in Colab
def display_video(video_file):
    video_type = video_file.split('.')[-1]  # Get video file extension
    video = open(video_file, "rb").read()
    data_url = "data:video/{};base64,".format(video_type) + b64encode(video).decode()
    return HTML('<video width="600" controls><source src="{}" type="video/{}"></video>'.format(data_url, video_type))

# Display the converted .mp4 video
display_video(output_path)

! yolo pose predict model=yolo11x-pose.pt source='/content/12 YEAR OLD KID PITCHING AT 90 MPH UNBELIEVABLE!!😱 #shorts #mlb #baseball #pitching #worldrecord.mp4' save=True


#Display output

from IPython.display import HTML
from base64 import b64encode
import os

# Path to your video file
video_path = '/content/runs/pose/predict2/12 YEAR OLD KID PITCHING AT 90 MPH UNBELIEVABLE!!😱 #shorts #mlb #baseball #pitching #worldrecord.avi'

# Convert .avi to .mp4 using ffmpeg (show only progress bar, no verbose output)
output_path = "Pose estimation.mp4"
# !apt-get install ffmpeg -y
# Use f-strings for variable substitution and ensure the output file extension is .mp4
# !ffmpeg -i "{video_path}" -vcodec libx264 -loglevel quiet -stats "{output_path}"

# Function to display video in Colab
def display_video(video_file):
    video_type = video_file.split('.')[-1]  # Get video file extension
    video = open(video_file, "rb").read()
    data_url = "data:video/{};base64,".format(video_type) + b64encode(video).decode()
    return HTML('<video width="600" controls><source src="{}" type="video/{}"></video>'.format(data_url, video_type))

# Display the converted .mp4 video
display_video(output_path)

! yolo classify predict model=yolo11x-pose.pt source='/content/Wolf Walks Along Road in Yellowstone __ ViralHog.mp4' save=True

#Display output

from IPython.display import HTML
from base64 import b64encode
import os

# Path to your video file
video_path = '/content/runs/pose/predict3/Wolf Walks Along Road in Yellowstone __ ViralHog.avi'

# Convert .avi to .mp4 using ffmpeg (show only progress bar, no verbose output)
output_path = "Image classification.mp4"
# !apt-get install ffmpeg -y
# Use f-strings for variable substitution and ensure the output file extension is .mp4
# !ffmpeg -i "{video_path}" -vcodec libx264 -loglevel quiet -stats "{output_path}"

# Function to display video in Colab
def display_video(video_file):
    video_type = video_file.split('.')[-1]  # Get video file extension
    video = open(video_file, "rb").read()
    data_url = "data:video/{};base64,".format(video_type) + b64encode(video).decode()
    return HTML('<video width="600" controls><source src="{}" type="video/{}"></video>'.format(data_url, video_type))

# Display the converted .mp4 video
display_video(output_path)

! yolo obb predict model=yolo11x-obb.pt source='/content/videoplayback.mp4' save=True

#Display output

from IPython.display import HTML
from base64 import b64encode
import os

# Path to your video file
video_path = '/content/runs/obb/predict/videoplayback.avi'
# Convert .avi to .mp4 using ffmpeg (show only progress bar, no verbose output)
output_path = "obb.mp4"
# !apt-get install ffmpeg -y
# Use f-strings for variable substitution and ensure the output file extension is .mp4
# !ffmpeg -i "{video_path}" -vcodec libx264 -loglevel quiet -stats "{output_path}"

# Function to display video in Colab
def display_video(video_file):
    video_type = video_file.split('.')[-1]  # Get video file extension
    video = open(video_file, "rb").read()
    data_url = "data:video/{};base64,".format(video_type) + b64encode(video).decode()
    return HTML('<video width="600" controls><source src="{}" type="video/{}"></video>'.format(data_url, video_type))

# Display the converted .mp4 video
display_video(output_path)
